# %%
#CONTENTS LIST:
#1. Complete wrangling and consistency checks for customers dataset

#2. #Change the data type of user_id and order_id to string

#3. Export of orders_products_aggregated_all.pkl

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Creating string for project folder path
path=r"C:\Users\HP\02-2024 Instacart Basket Analysis"

# %%
"""
File:customers.csv
Author:Erica Henry
Date: 2/28/24

#Description: Importing of raw data for customers.csv
"""

df_cust=pd.read_csv(os.path.join(path,"02 Data","Original Data","customers.csv"),index_col= False)

# %%
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#Changing column name Surnam to Last Name
df_cust.rename(columns={"Surnam":"Last Name"},inplace=True)

# %%
#Changing column name STATE to State
df_cust.rename(columns={"STATE":"State"},inplace=True)

# %%
#Changing column name n_dependants to number_of_dependents
df_cust.rename(columns={"n_dependants":"number_of_dependents"},inplace=True)

# %%
df_cust.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
#Exporting df_cust dataframe as customers_wrangled.csv
df_cust.to_csv(os.path.join(path,"02 Data","Prepared Data","customers_wrangled.csv"))

# %%
"""
File:customers_wrangled.csv
Author:Erica Henry
Date: 2/28/24

#Description: Importing data for customers_wrangled.csv
"""

df_cust=pd.read_csv(os.path.join(path,"02 Data","Prepared Data","customers_wrangled.csv"),index_col= 0)

# %%
df_cust.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
"""
File:customers_wrangled.csv
Author:Erica Henry
Date: 2/28/24

#Description: Check for mixed types in df_cust
"""

#check for mixed types in df_cust
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13368\1244628817.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_13368\1244628817.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_13368\1244628817.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# First Name
# C:\Users\HP\AppData\Local\Temp\ipykernel_13368\1244628817.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
"""
File:customers_wrangled.csv
Author:Erica Henry
Date: 2/28/24

#Description: Find missing values in df_cust
"""

df_cust.isnull().sum()
# Out:
# user_id                     0
# First Name              11259
# Last Name                   0
# Gender                      0
# State                       0
# Age                         0
# date_joined                 0
# number_of_dependents        0
# fam_status                  0
# income                      0
# dtype: int64

# %%
"""
File:customers_wrangled.csv
Author:Erica Henry
Date: 2/28/24

#Description: Finding duplicates df_cust
"""

df_dups = df_cust[df_cust.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, number_of_dependents, fam_status, income]
# Index: []

# %%
#Exporting df_cust dataframe as df_cust_new_consistency_checked
df_cust.to_csv(os.path.join(path,"02 Data","Prepared Data","df_cust_new_consistency_checked.csv"))

# %%
"""
File: df_cust_new_consistency_checked.csv
Author:Erica Henry
Date: 2/28/24

#Description: Importing df_cust_new_consistency_checked
"""

df_cust=pd.read_csv(os.path.join(path,"02 Data","Prepared Data","df_cust_new_consistency_checked.csv"),index_col= 0)

# %%
"""
File: orders_products_aggregated1.pkl
Author:Erica Henry
Date: 2/28/24

#Description: Importing orders_products_aggregated1
"""

ords_prods_agg=pd.read_pickle(os.path.join(path,"02 Data","Prepared Data","orders_products_aggregated1.pkl"))

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               206209 non-null  int64
#  1   First Name            194950 non-null  object
#  2   Last Name             206209 non-null  object
#  3   Gender                206209 non-null  object
#  4   State                 206209 non-null  object
#  5   Age                   206209 non-null  int64
#  6   date_joined           206209 non-null  object
#  7   number_of_dependents  206209 non-null  int64
#  8   fam_status            206209 non-null  object
#  9   income                206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 17.3+ MB

# %%
#Check the output of df_cust
df_cust.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
#Check the output of ords_prods_agg
ords_prods_agg.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2398795        1                 2                   3                  7
# 2    473747        1                 3                   3                 12
# 3   2254736        1                 4                   4                  7
# 4    431534        1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  \
# 0                     NaN         196                  1
# 1                    15.0         196                  1
# 2                    21.0         196                  1
# 3                    29.0         196                  1
# 4                    28.0         196                  1
#
#    number_of_times_reordered  Unnamed: 0  ...    price_range_loc  \
# 0                          0         195  ...  Mid-range product
# ...

# %%
ords_prods_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   int64
#  1   user_id                    int64
#  2   number_of_orders           int64
#  3   orders_day_of_week         int64
#  4   order_hour_of_day          int64
#  5   days_since_prior_order     float64
#  6   product_id                 int64
#  7   add_to_cart_order          int64
#  8   number_of_times_reordered  int64
#  9   Unnamed: 0                 int64
#  10  product_name               object
#  11  aisle_id                   int64
#  12  department_id              int64
#  13  prices                     float64
#  14  _merge                     category
#  15  price_range_loc            object
#  16  busiest_day                object
#  17  busiest_days               object
#  18  busiest_period_of_day      object
# ...

# %%
#Change the data type of user_id to string in ords_prods_agg
ords_prods_agg["user_id"] = ords_prods_agg["user_id"].astype("str")

# %%
#Change the data type of order_id to string in ords_prods_agg
ords_prods_agg['order_id'] = ords_prods_agg['order_id'].astype('str')

# %%
#Change the data type of user_id to string in df_cust
df_cust['user_id'] = df_cust['user_id'].astype('str')

# %%
#Drop columns _merge and Unnamed: 0 from ords_prods_agg, not needed
ords_prods_agg = ords_prods_agg.drop(columns = ['_merge', 'Unnamed: 0'])

# %%
#Drop column date_joined from df_cust, not needed
df_cust= df_cust.drop(columns = ['date_joined'])

# %%
#Check output
ords_prods_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 23 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   object
#  1   user_id                    object
#  2   number_of_orders           int64
#  3   orders_day_of_week         int64
#  4   order_hour_of_day          int64
#  5   days_since_prior_order     float64
#  6   product_id                 int64
#  7   add_to_cart_order          int64
#  8   number_of_times_reordered  int64
#  9   product_name               object
#  10  aisle_id                   int64
#  11  department_id              int64
#  12  prices                     float64
#  13  price_range_loc            object
#  14  busiest_day                object
#  15  busiest_days               object
#  16  busiest_period_of_day      object
#  17  max_order                  int64
#  18  loyalty_flag               object
# ...

# %%
"""
File:orders_products_aggregated1.pkl and df_cust_new_consistency_checked.csv
Author:Erica Henry
Date: 2/28/24

#Description: Combining df_customers and ords_prods_agg
"""

ords_prods_agg_all = ords_prods_agg.merge(df_cust, on = ["user_id"], indicator = True)

# %%
#Check the output of ords_prods_agg_all
ords_prods_agg_all.shape
# Out:
# (32404859, 32)

# %%
ords_prods_agg_all.head()
# Out:
#   order_id user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1                 1                   2                  8
# 1  2398795       1                 2                   3                  7
# 2   473747       1                 3                   3                 12
# 3  2254736       1                 4                   4                  7
# 4   431534       1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  \
# 0                     NaN         196                  1
# 1                    15.0         196                  1
# 2                    21.0         196                  1
# 3                    29.0         196                  1
# 4                    28.0         196                  1
#
#    number_of_times_reordered product_name  ...     Frequency flag  First Name  \
# 0                          0         Soda  ...  Frequent customer       Linda
# ...

# %%
#Exporting merged df ords_prods_agg_all as df_cust_new_consistency_checked
ords_prods_agg_all.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated_all.pkl'))
